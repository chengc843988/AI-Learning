# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('emboss.jpg')

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
#just for debug+ 可以秀出dst[102,12] 是底下
#img[100:105,10:15] 加總後*1/25的平均值
print(img.shape)
print('orignal_100:',img[100,10:15])
print('orignal_101:',img[101,10:15])
print('orignal_102:',img[102,10:15])
print('orignal_103:',img[103,10:15])
print('orignal_104:',img[104,10:15])
print('Blur:',dst[102,12])
#just for debug-
#used another kernel 9x9
kernel2 = np.ones((9,9),np.float32)/81
dst2 = cv2.filter2D(img,-1,kernel2)
# Out:
# (297, 541, 3)
# orignal_100: [[251 251 251]
#  [249 249 249]
#  [248 248 248]
#  [245 245 245]
#  [243 243 243]]
# orignal_101: [[251 251 251]
#  [249 249 249]
#  [248 248 248]
#  [245 245 245]
#  [243 243 243]]
# orignal_102: [[251 251 251]
#  [249 249 249]
#  [248 248 248]
#  [245 245 245]
#  [243 243 243]]
# orignal_103: [[251 251 251]
#  [249 249 249]
#  [248 248 248]
#  [245 245 245]
#  [243 243 243]]
# orignal_104: [[251 251 251]
#  [249 249 249]
#  [248 248 248]
#  [245 245 245]
#  [243 243 243]]
# Blur: [247 247 247]

# %%
#====show result===
plt.figure(figsize=(50,50))
#plt.subplot(131, plt.imshow(img),plt.title('Original')
plt.subplot(131), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(dst),plt.title('Averaging5x5')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(dst2),plt.title('Averaging9x9')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.imshow(dst2)
plt.imshow(img)
plt.show()

# %%
kernel = np.ones((9,9),np.float32)/81
dstX = cv2.filter2D(img,-1,kernel)
plt.imshow(dstX)
# plt.imshow(img)
plt.show()

# %%
kernel = np.ones((3,3),np.float32)/1
#  kernel = np.array([0,1,0],[1,-4.1],[0,1,0])
kernel[0][0]=-1
kernel[0][1]=-1
kernel[0][2]=-1
kernel[1][0]=0
kernel[1][1]=0
kernel[1][2]=0
kernel[2][0]=1
kernel[2][1]=1
kernel[2][2]=1
print (kernel)
dstX = cv2.filter2D(img,-1,kernel)
plt.figure(figsize=(50,50))
plt.subplot(131)
plt.imshow(img)
plt.subplot(132)
plt.imshow(dstX)
# plt.imshow(img)
plt.show()
# Out:
# [[-1. -1. -1.]
#  [ 0.  0.  0.]
#  [ 1.  1.  1.]]

# %%
kernel_1 = np.ones((3,3),np.float32)
#  kernel = np.array([0,1,0],[1,-4.1],[0,1,0])
kernel_1[0][0]=-2
kernel_1[0][1]=-2
kernel_1[0][2]=-2
kernel_1[1][0]=0
kernel_1[1][1]=0
kernel_1[1][2]=0
kernel_1[2][0]=2
kernel_1[2][1]=2
kernel_1[2][2]=2

kernel_2 = np.ones((3,3),np.float32)
kernel_2[0][0]=-2
kernel_2[0][1]=0
kernel_2[0][2]=2
kernel_2[1][0]=-2
kernel_2[1][1]=0
kernel_2[1][2]=2
kernel_2[2][0]=-2
kernel_2[2][1]=0
kernel_2[2][2]=2

print ('Kernel1=', kernel_1)
print ('Kernel2=', kernel_2)

dst_1 = cv2.filter2D(img,-1,kernel_1)
dst_2 = cv2.filter2D(dst_1,-1,kernel_2)

plt.figure(figsize=(40,40))
plt.subplot(131)
plt.imshow(img)
plt.subplot(132)
plt.imshow(dst_1)
plt.subplot(133)
plt.imshow(dst_2)
plt.show()
# Out:
# Kernel1= [[-2. -2. -2.]
#  [ 0.  0.  0.]
#  [ 2.  2.  2.]]
# Kernel2= [[-2.  0.  2.]
#  [-2.  0.  2.]
#  [-2.  0.  2.]]

# %% [markdown]
# #### import cv2
# import numpy as np
# from matplotlib import pyplot as plt
#
# img = cv2.imread('emboss.jpg')
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# blur = cv2.boxFilter(img,(5,5)) # cv2.boxFilter(img,(5,5))
# median = cv2.medianBlur(img,5)
# GaussianBlur = cv2.GaussianBlur(img,(5,5),0)
# bilateralFilter = cv2.bilateralFilter(img,9,75,75)
#
# #==畫出結果====
# plt.subplot(231),plt.imshow(img),plt.title('Original')
# plt.xticks([]), plt.yticks([])
# plt.subplot(232),plt.imshow(blur),plt.title('boxFilter')
# plt.xticks([]), plt.yticks([])
# plt.subplot(233),plt.imshow(median),plt.title('medianBlur')
# plt.xticks([]), plt.yticks([])
# plt.subplot(234),plt.imshow(GaussianBlur),plt.title('GaussianBlur')
# plt.xticks([]), plt.yticks([])
# plt.subplot(235),plt.imshow(bilateralFilter),plt.title('bilateralFilter')
# plt.xticks([]), plt.yticks([])
# plt.show()
